# %%
import numpy as np

a = np.array([10, 20, 30])
b = np.array([1, 2, 3])

# %%
print(a + b)
# Out:
# [11 22 33]

# %%
X = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# %%
X+10
# Out:
# array([[ 20,  30,  40],
#        [ 50,  60,  70],
#        [ 80,  90, 100]])

# %%
X*2
# Out:
# array([[ 20,  40,  60],
#        [ 80, 100, 120],
#        [140, 160, 180]])

# %%
X + np.array([1, 2, 3])
# Out:
# array([[11, 22, 33],
#        [41, 52, 63],
#        [71, 82, 93]])

# %%
X + np.array([[1], [2], [3]])
# Out:
# array([[11, 21, 31],
#        [42, 52, 62],
#        [73, 83, 93]])

# %%
X * np.array([2, 3, 4])
# Out:
# array([[ 20,  60, 120],
#        [ 80, 150, 240],
#        [140, 240, 360]])

# %%
# X.shape = (100, 4)
# weights.shape = (4,)

# X*weights = ?
