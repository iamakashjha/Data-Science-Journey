# %%
name = "Akash"
print(f"Hello, {name}!")
# Out:
# Hello, Akash!

# %%
Age = 20
print(f"Hello, {name}! You are {Age} years old.")
# Out:
# Hello, Akash! You are 20 years old.

# %%
Height = 5.5
print(f"Hello, {name}! You are {Age} years old and your height is {Height} feet.")
# Out:
# Hello, Akash! You are 20 years old and your height is 5.5 feet.

# %%
language = "Python"
print(f"Hello, {name}! You are {Age} years old, your height is {Height} feet, and you like {language}.")
# Out:
# Hello, Akash! You are 20 years old, your height is 5.5 feet, and you like Python.

# %%
job_role = "Data Scientist"
print(f"Hello, {name}! You are {Age} years old, your height is {Height} feet, you like {language}, and your job role is {job_role}.")
# Out:
# Hello, Akash! You are 20 years old, your height is 5.5 feet, you like Python, and your job role is Data Scientist.

# %%
print(type(name))
print(type(Age))
print(type(Height))
print(type(language))
print(type(job_role))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
name = "Rahul"
age = 21
cgpa = 8.7
is_placed = False

print("Student Information")
print("-------------------")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"CGPA: {cgpa}")
print(f"Placed: {is_placed}")
# Out:
# Student Information
# -------------------
# Name: Rahul
# Age: 21
# CGPA: 8.7
# Placed: False
