# %% [markdown]
# ⭐ Bonus Challenge
#
# Dataset:
# ```
# employees = (
#     ("Alice", 60000),
#     ("Bob", 50000),
#     ("Charlie", 70000)
# )
# ```
# Write a program to:
#
# - Print every employee
# - Find the highest salary
# - Print the employee who earns it
#
# Do this without converting the tuple into a list.

# %%
employees = (
    ("Alice", 60000),
    ("Bob", 50000),
    ("Charlie", 70000)
)

# %%
name = []
salary = []

for emp in employees:
    name, salary = emp
    print(f"Employee: {name}, Salary: {salary}")
# Out:
# Employee: Alice, Salary: 60000
# Employee: Bob, Salary: 50000
# Employee: Charlie, Salary: 70000

# %%
print(max(emp[1] for emp in employees))
# Out:
# 70000
